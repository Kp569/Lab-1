# %% [markdown]
# #Lab 1

# %%
import pandas as pd

# %% [markdown]
# # Pupose:
# The purpose of this procedure was to learn how to transfer measurements from English measurements to metric measurements.

# %% [markdown]
# # Procedure:
# 1. Become familiar with the basic metric units of measure.
# 2. Learn the basic unit of each measurement.
# 3. Understand the significance of the prefixes of each unit.
# 4. Complete the worksheet on page 6 using the following information.

# %% [markdown]
# #Linear Measurement:

# %% [markdown]
# ![image.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Volume Measurement:

# %%
df = pd.read_excel (r'./lab 1 copy.xlsx')
df
# Out:
#   Milimeters Centimeters
# 0      280mm        28cm
# 1      260mm        26cm

# %% [markdown]
# #Mass Measurement:

# %%
mm = pd.read_excel (r'./lab1 part 2 - Copy.xlsx')
mm
# Out:
#    Miligrams    grams
# 0   112610mg  112.61g
# 1  2014440mg  201.44g

# %% [markdown]
# #pH Measurement:

# %%
pH = pd.read_excel (r'./Lab1 part 3.xlsx')
pH
# Out:
#   Items  pH level
# 0     A         2
# 1     B         6
# 2     C        11

# %% [markdown]
# #Time Measurement:

# %%
tm = pd.read_excel (r'./Lab1 part 4.xlsx')
tm
# Out:
#               Column1  Pulse Rate after 15 seconds   \
# 0      Beats /seconds                            17
# 1      Beats / minute                            68
# 2  Beats / Milisecond                             0
#
#    Pulse Rate after 60 seonds
# 0                         15.3
# 1                         61.0
# 2                      15300.0

# %% [markdown]
# #Discussion:
# In linear measurements, we converted mm to cm by dividing the outcome by 10.in volume measurements, we converted mL to L by dividing the outcome by 1000. In mass measurements, we converted mg to g by dividing the outcomes by 1000. inpH measurements, we measurd each liquid in seperate conatineers. In time meaurement, we were abke to count our pulse rate from seconds to minutes.

# %% [markdown]
# #Conclusion:
# In order to aquire accuarte data we must be able to use metric system and convert values from the english system to the metric system.
